# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv(r"C:\Users\pnman\OneDrive\Desktop\learn.csv")

# %%
dataframe.head(5)
# Out:
#   ISO3 PRODUCT_NAME                 VACCINE_NAME     COMPANY_NAME  \
# 0  SHN      AZD1222        AstraZeneca - AZD1222      AstraZeneca
# 1  GRL    mRNA-1273          Moderna - mRNA-1273          Moderna
# 2  FRO    mRNA-1273          Moderna - mRNA-1273          Moderna
# 3  FRO    Comirnaty  Pfizer BioNTech - Comirnaty  Pfizer BioNTech
# 4  JEY    mRNA-1273          Moderna - mRNA-1273          Moderna
#
#   AUTHORIZATION_DATE START_DATE  END_DATE  COMMENT DATA_SOURCE
# 0                NaN        NaN       NaN      NaN        OWID
# 1                NaN        NaN       NaN      NaN        OWID
# 2                NaN        NaN       NaN      NaN        OWID
# 3                NaN        NaN       NaN      NaN        OWID
# 4                NaN        NaN       NaN      NaN        OWID

# %%
dataframe.isnull().sum()
# Out:
# ISO3                     0
# PRODUCT_NAME             7
# VACCINE_NAME             0
# COMPANY_NAME            51
# AUTHORIZATION_DATE     928
# START_DATE             795
# END_DATE              1105
# COMMENT               1105
# DATA_SOURCE              0
# dtype: int64

# %%
dataframe.shape
# Out:
# (1105, 9)

# %%
sns.heatmap(dataframe.isnull())
plt.show()

# %%
dataframe.drop(columns=["END_DATE","COMMENT"],inplace=True)

# %%
dataframe.shape
# Out:
# (1105, 5)

# %%
dataframe.isnull().sum()
# Out:
# ISO3             0
# PRODUCT_NAME     7
# VACCINE_NAME     0
# COMPANY_NAME    51
# DATA_SOURCE      0
# dtype: int64

# %%
sns.heatmap(dataframe.isnull())
plt.show()

# %%
dataframe.dropna(inplace=True)

# %%
dataframe.isnull().sum()
# Out:
# ISO3            0
# PRODUCT_NAME    0
# VACCINE_NAME    0
# COMPANY_NAME    0
# DATA_SOURCE     0
# dtype: int64

# %%
sns.heatmap(dataframe.isnull())
plt.show()

# %%
dataframe.shape
# Out:
# (1054, 5)
